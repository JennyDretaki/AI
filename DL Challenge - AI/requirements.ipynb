# %% [markdown]
# ## **Requirements file for Dinosaur Image Classification Challenge**

# %% [markdown]
# **Core libraries for numerical operations and data handling**

# %% [markdown]
# numpy==1.24.3 # For array operations and numerical computations pandas==2.0.3 # For handling CSV files and dataframes

# %% [markdown]
# **Visualization libraries**

# %% [markdown]
# matplotlib==3.7.2 # For plotting (e.g., training curves, EDA visualizations) seaborn==0.12.2 # For enhanced visualizations (e.g., bar plots, heatmaps)

# %% [markdown]
# **Image processing libraries**

# %% [markdown]
# opencv-python==4.8.0.76 # For reading and processing images (e.g., dimensions, color analysis) Pillow==10.0.0 # For verifying image integrity and handling image files

# %% [markdown]
# **Deep learning library**

# %% [markdown]
# tensorflow==2.13.0 # For building, training, and evaluating the MobileNetV2 model

# %% [markdown]
# **Machine learning metrics**

# %% [markdown]
# cikit-learn==1.3.0 # For confusion matrix and classification report
